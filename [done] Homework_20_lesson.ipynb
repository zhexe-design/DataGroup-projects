# %% [markdown]
# # Домашнее задание: Анализ многомерных данных
# ## Неделя 10, Занятие 20: Снижение размерности

# %% [markdown]
# ## 1. Введение
#
# На этом занятии вы будете работать с методами снижения размерности (PCA и t-SNE). Ваша задача применить эти методы к реальному датасету, проанализировать результаты и сравнить их эффективность.
#
# ### Цель задания:
# - Понять, как работает PCA и его ограничения
# - Применить t-SNE для нелинейного снижения размерности
# - Применить оба метода для визуализации данных
# - Сравнить результаты и выбрать оптимальный метод
# - Использовать результаты для улучшения кластеризации

# %% [markdown]
# ## 2. Описание датасета
#
# В этом задании вы работаете с датасетом MNIST (Modified National Institute of Standards and Technology Database) — классическим датасетом рукописных цифр.
#
# **Характеристики:**
# - **Объекты:** 1797 образцов рукописных цифр (0-9)
# - **Признаки:** 64 (8×8 пиксели, значения 0-16)
# - **Классы:** 10 (цифры от 0 до 9)
# - **Размерность:** 64-мерное пространство
#
# **Задача:** Применить методы снижения размерности, чтобы:
# - Визуализировать данные в 2D
# - Выявить структуру данных
# - Улучшить кластеризацию

# %% [markdown]
# ## 3. Загрузка и подготовка данных

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_digits
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# Загружаем датасет
digits = load_digits()

X = digits.data
y = digits.target

print("Датасет загружен")
print(f"Форма: {X.shape}")
print(f"Количество объектов: {X.shape[0]}")
print(f"Количество признаков: {X.shape[1]}")
print(f"Количество классов: {len(np.unique(y))}")
# Out:
# Датасет загружен
# Форма: (1797, 64)
# Количество объектов: 1797
# Количество признаков: 64
# Количество классов: 10

# %% [markdown]
# ## 4. Часть 1: Предварительный анализ данных
#
# **Задания:**
# 1. Визуализируйте примеры из датасета
# 2. Посчитайте статистику по признакам
# 3. Проверьте распределение классов

# %%
fig, axes = plt.subplots(2, 5, figsize=(10, 5))

for i, ax in enumerate(axes.flat):
    ax.imshow(digits.images[i], cmap='gray')
    ax.set_title(f'Цифра: {digits.target[i]}')
    ax.axis('off')

plt.tight_layout()
plt.show()

df = pd.DataFrame(X)

print(df.describe())

unique, counts = np.unique(y, return_counts=True)

plt.figure(figsize=(8,5))

plt.bar(unique, counts)

plt.xlabel('Цифра')
plt.ylabel('Количество')
plt.title('Распределение классов')

plt.show()
# Out:
#            0            1            2            3            4   \
# count  1797.0  1797.000000  1797.000000  1797.000000  1797.000000
# mean      0.0     0.303840     5.204786    11.835838    11.848080
# std       0.0     0.907192     4.754826     4.248842     4.287388
# min       0.0     0.000000     0.000000     0.000000     0.000000
# 25%       0.0     0.000000     1.000000    10.000000    10.000000
# 50%       0.0     0.000000     4.000000    13.000000    13.000000
# 75%       0.0     0.000000     9.000000    15.000000    15.000000
# max       0.0     8.000000    16.000000    16.000000    16.000000
#
#                 5            6            7            8            9   ...  \
# count  1797.000000  1797.000000  1797.000000  1797.000000  1797.000000  ...
# mean      5.781859     1.362270     0.129661     0.005565     1.993879  ...
# std       5.666418     3.325775     1.037383     0.094222     3.196160  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 50%       4.000000     0.000000     0.000000     0.000000     0.000000  ...
# 75%      11.000000     0.000000     0.000000     0.000000     3.000000  ...
# max      16.000000    16.000000    15.000000     2.000000    16.000000  ...
#
#                 54           55           56           57           58  \
# count  1797.000000  1797.000000  1797.000000  1797.000000  1797.000000
# mean      3.725097     0.206455     0.000556     0.279354     5.557596
# std       4.919406     0.984401     0.023590     0.934302     5.103019
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     1.000000
# 50%       1.000000     0.000000     0.000000     0.000000     4.000000
# 75%       7.000000     0.000000     0.000000     0.000000    10.000000
# max      16.000000    13.000000     1.000000     9.000000    16.000000
#
#                 59           60           61           62           63
# count  1797.000000  1797.000000  1797.000000  1797.000000  1797.000000
# mean     12.089037    11.809126     6.764051     2.067891     0.364496
# std       4.374694     4.933947     5.900623     4.090548     1.860122
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      11.000000    10.000000     0.000000     0.000000     0.000000
# 50%      13.000000    14.000000     6.000000     0.000000     0.000000
# 75%      16.000000    16.000000    12.000000     2.000000     0.000000
# max      16.000000    16.000000    16.000000    16.000000    16.000000
#
# [8 rows x 64 columns]

# %% [markdown]
# ## 5. Часть 2: Стандартизация данных

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

print("Данные стандартизированы")

print(f"Среднее: {X_scaled.mean():.6f}")
print(f"Стандартное отклонение: {X_scaled.std():.6f}")
# Out:
# Данные стандартизированы
# Среднее: 0.000000
# Стандартное отклонение: 0.976281

# %% [markdown]
# ## 6. Часть 3: PCA (Principal Component Analysis)
#
# **Задания:**
# 1. Вычислите объясненную дисперсию для каждой компоненты
# 2. Постройте график кумулятивной дисперсии
# 3. Определите, сколько компонент нужно для 95% и 99% дисперсии
# 4. Примените PCA для 2D визуализации
# 5. Визуализируйте результаты

# %%
pca_full = PCA()

pca_full.fit(X_scaled)

explained_variance = pca_full.explained_variance_ratio_

print(explained_variance)

# 2. График кумулятивной дисперсии
cumsum_var = np.cumsum(pca_full.explained_variance_ratio_)

plt.figure(figsize=(10,6))

plt.plot(cumsum_var, marker='o')

plt.xlabel('Количество компонент')
plt.ylabel('Кумулятивная дисперсия')
plt.title('PCA: Кумулятивная объясненная дисперсия')

plt.grid()

plt.show()

# 3. Найти количество компонент
n_components_95 = np.argmax(cumsum_var >= 0.95) + 1
n_components_99 = np.argmax(cumsum_var >= 0.99) + 1

print(f"Для 95% дисперсии нужно: {n_components_95} компонент")
print(f"Для 99% дисперсии нужно: {n_components_99} компонент")
# Out:
# [0.12033916 0.09561054 0.08444415 0.06498408 0.04860155 0.0421412
#  0.03942083 0.03389381 0.02998221 0.02932003 0.02781805 0.02577055
#  0.02275303 0.0222718  0.02165229 0.01914167 0.01775547 0.01638069
#  0.0159646  0.01489191 0.0134797  0.01271931 0.01165837 0.01057647
#  0.00975316 0.00944559 0.00863014 0.00836643 0.00797693 0.00746471
#  0.00725582 0.00691911 0.00653909 0.00640793 0.00591384 0.00571162
#  0.00523637 0.00481808 0.00453719 0.00423163 0.00406053 0.00397085
#  0.00356493 0.00340787 0.00327835 0.00311032 0.00288575 0.00276489
#  0.00259175 0.00234483 0.00218257 0.00203598 0.00195512 0.00183318
#  0.00167946 0.00161236 0.00147763 0.00135118 0.00125101 0.00103696
#  0.00082535 0.         0.         0.        ]
# Для 95% дисперсии нужно: 40 компонент
# Для 99% дисперсии нужно: 54 компонент

# %%
pca_2d = PCA(n_components=2)

X_pca_2d = pca_2d.fit_transform(X_scaled)

print(X_pca_2d.shape)


plt.figure(figsize=(10,7))

scatter = plt.scatter(
    X_pca_2d[:, 0],
    X_pca_2d[:, 1],
    c=y,
    cmap='tab10',
    s=30
)

plt.xlabel('PC1')
plt.ylabel('PC2')

plt.title('PCA 2D Visualization')

plt.colorbar(scatter)

plt.show()

print(f"Объясненная дисперсия: {pca_2d.explained_variance_ratio_.sum():.2%}")
# Out:
# (1797, 2)
# Объясненная дисперсия: 21.59%

# %% [markdown]
# ## 7. Часть 4: t-SNE (t-Distributed Stochastic Neighbor Embedding)
#
# **Задания:**
# 1. Примените PCA 50D (предварительное снижение размерности)
# 2. Примените t-SNE к PCA 50D
# 3. Визуализируйте результаты
# 4. Экспериментируйте с параметром perplexity

# %%
pca_50 = PCA(n_components=50)

X_pca_50 = pca_50.fit_transform(X_scaled)

print(f"PCA 50D: объясненная дисперсия = {pca_50.explained_variance_ratio_.sum():.2%}")
# Out:
# PCA 50D: объясненная дисперсия = 98.28%

# %%
print("Применяю t-SNE...")

tsne = TSNE(
    n_components=2,
    perplexity=30,
    n_iter=1000,
    random_state=42
)

X_tsne = tsne.fit_transform(X_pca_50)

print("t-SNE завершен")

plt.figure(figsize=(10,7))

scatter = plt.scatter(
    X_tsne[:, 0],
    X_tsne[:, 1],
    c=y,
    cmap='tab10',
    s=30
)

plt.title('t-SNE Visualization')

plt.colorbar(scatter)

plt.show()
# Out:
# Применяю t-SNE...
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# t-SNE завершен

# %%
perplexities = [5, 30, 50]

fig, axes = plt.subplots(1, 3, figsize=(18,5))

for i, perplexity in enumerate(perplexities):

    tsne = TSNE(
        n_components=2,
        perplexity=perplexity,
        n_iter=1000,
        random_state=42
    )

    X_tsne_temp = tsne.fit_transform(X_pca_50)

    axes[i].scatter(
        X_tsne_temp[:, 0],
        X_tsne_temp[:, 1],
        c=y,
        cmap='tab10',
        s=15
    )

    axes[i].set_title(f'Perplexity = {perplexity}')

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %% [markdown]
# ## 8. Часть 5: Сравнение методов
#
# **Задания:**
# 1. Визуализируйте результаты PCA и t-SNE рядом
# 2. Сравните время выполнения
# 3. Напишите вывод о различиях

# %%
fig, axes = plt.subplots(1, 2, figsize=(14,6))

# PCA
axes[0].scatter(
    X_pca_2d[:, 0],
    X_pca_2d[:, 1],
    c=y,
    cmap='tab10',
    s=20
)

axes[0].set_title('PCA')

# t-SNE
axes[1].scatter(
    X_tsne[:, 0],
    X_tsne[:, 1],
    c=y,
    cmap='tab10',
    s=20
)

axes[1].set_title('t-SNE')

plt.tight_layout()
plt.show()

import time

# PCA
t_start = time.time()

pca_test = PCA(n_components=2)
X_pca_test = pca_test.fit_transform(X_scaled)

t_pca = time.time() - t_start

# t-SNE
t_start = time.time()

tsne_test = TSNE(
    n_components=2,
    perplexity=30,
    n_iter=1000,
    random_state=42
)

X_tsne_test = tsne_test.fit_transform(X_pca_50)

t_tsne = time.time() - t_start

print(f"Время PCA: {t_pca:.3f} сек")
print(f"Время t-SNE: {t_tsne:.3f} сек")
print(f"t-SNE медленнее в {t_tsne/t_pca:.1f} раз")
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# Время PCA: 0.002 сек
# Время t-SNE: 8.920 сек
# t-SNE медленнее в 3600.4 раз

# %% [markdown]
# ## 9. Часть 6: Применение для кластеризации
#
# **Задания:**
# 1. Примените K-Means к исходным данным
# 2. Примените K-Means к PCA проекции
# 3. Примените K-Means к t-SNE проекции
# 4. Сравните качество (silhouette score)
# 5. Визуализируйте результаты

# %%
# K-Means на разных данных
kmeans_original = KMeans(n_clusters=10, random_state=42, n_init=10)
labels_original = kmeans_original.fit_predict(X_scaled)

kmeans_pca = KMeans(n_clusters=10, random_state=42, n_init=10)
labels_pca = kmeans_pca.fit_predict(X_pca_50)

kmeans_tsne = KMeans(n_clusters=10, random_state=42, n_init=10)
labels_tsne = kmeans_tsne.fit_predict(X_tsne)

# Силуэтные коэффициенты
score_original = silhouette_score(X_scaled, labels_original)
score_pca = silhouette_score(X_pca_50, labels_pca)
score_tsne = silhouette_score(X_tsne, labels_tsne)

print(f"Silhouette Score (исходные): {score_original:.3f}")
print(f"Silhouette Score (PCA 50D): {score_pca:.3f}")
print(f"Silhouette Score (t-SNE 2D): {score_tsne:.3f}")
# Out:
# Silhouette Score (исходные): 0.139
# Silhouette Score (PCA 50D): 0.151
# Silhouette Score (t-SNE 2D): 0.573

# %%
# Визуализация
fig, axes = plt.subplots(2, 3, figsize=(16, 10))

# Истинные метки
scatter1 = axes[0, 0].scatter(X_pca_2d[:, 0], X_pca_2d[:, 1], c=y, cmap='tab10', s=30)
axes[0, 0].set_title('PCA: Истинные метки')

scatter2 = axes[0, 1].scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, cmap='tab10', s=30)
axes[0, 1].set_title('t-SNE: Истинные метки')

# Предсказанные кластеры
scatter3 = axes[1, 0].scatter(X_pca_2d[:, 0], X_pca_2d[:, 1], c=labels_original, cmap='viridis', s=30)
axes[1, 0].set_title(f'PCA: K-Means (Score: {score_original:.3f})')

scatter4 = axes[1, 1].scatter(X_tsne[:, 0], X_tsne[:, 1], c=labels_tsne, cmap='viridis', s=30)
axes[1, 1].set_title(f't-SNE: K-Means (Score: {score_tsne:.3f})')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10. Анализ результатов
#
# **Напишите анализ:**
#
# 1. **Объясненная дисперсия:** Какой процент информации теряется при снижении с 64D до 2D?
#
# 2. **Сравнение методов:** Какой метод лучше сохраняет структуру данных?
#
# 3. **Кластеризация:** Как снижение размерности влияет на качество кластеризации?
#
# 4. **Практическое применение:** Когда использовать PCA, когда t-SNE?
#
# 5. **Проблемы и ограничения:** Какие недостатки каждого метода вы выявили?

# %% [markdown]
# ### Ваш анализ:
#
# При снижении размерности с 64 признаков до 2 компонент с помощью PCA сохраняется только часть исходной информации. При уменьшении размерности до 2D теряется значительная часть информации. Однако даже этих двух компонент достаточно, чтобы увидеть общую структуру данных и основные группы цифр.
#
# PCA старается сохранить максимальную дисперсию данных, поэтому первые компоненты содержат наиболее важную информацию.
#
# В PCA линейный метод снижения размерности, сохраняет глобальную структуру данных, быстро работает, хорошо подходит для предварительного анализа.
# На визуализации PCA классы цифр частично пересекаются.
#
# В t-SNE нелинейный метод, сохраняет локальную структуру данных, лучше разделяет похожие объекты. На графике t-SNE
# кластеры цифр разделяются значительно лучше, большинство классов образуют отдельные группы, структура данных становится более понятной визуально.
#
# PCA лучше:
# - для быстрого уменьшения размерности
# - для подготовки данных
# - для сохранения общей структуры
#
# t-SNE лучше:
# - для визуализации
# - для поиска скрытых закономерностей
# - для разделения сложных нелинейных структур
#
# После применения снижения размерности качество кластеризации может изменяться.
#
# K-Means на исходных данных
#
# Исходные 64D данные содержат много информации, но:
#
# высокая размерность усложняет кластеризацию
# некоторые признаки могут быть шумовыми
# K-Means после PCA
#
# PCA:
#
# удаляет шум
# оставляет наиболее важные компоненты
# ускоряет работу алгоритма
#
# Поэтому silhouette score часто:
#
# становится лучше
# либо почти не ухудшается.
#
# Снижение размерности помогает визуализировать данные, может улучшать кластеризацию, уменьшае шум и вычислительную сложностью. Но слишком сильное уменьшение размерности может привести к потере информации.
